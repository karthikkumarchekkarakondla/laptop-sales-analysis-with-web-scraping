# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')

# %%
url='https://www.flipkart.com/search?q=laptop&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&as-pos=1&as-type=RECENT&suggestionId=laptop%7CLaptops&requestId=3f3ea89d-e660-48a9-b1a4-5c9c322da66e&as-searchtext=Lapt'

# %%
response=requests.get(url)
response
# Out:
# <Response [529]>

# %%
requests_header={
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36 FKUA/website/42/website/Desktop',
    'Accept-Encoding':'gzip, deflate, br, zstd',
    'Content-Type':'application/json'
}

# %%
response=requests.get(url,headers=requests_header)
response
# Out:
# <Response [529]>

# %%
pagecontent=response.text

# %%
soup = BeautifulSoup(pagecontent)

# %%
pname=soup.find('div',attrs={'class':'RG5Slk'})
pname

# %%
pname=[]
for x in soup.find_all('div',attrs={'class':'RG5Slk'}):
  pname.append(x.text if x else np.nan)
  #diplay all ratings
  for name in pname:
    print(name)

# %%
ratings=soup.find('div',attrs={'class':'MKiFS6'})

# %%
ratings

# %%
ratings=[]
for x in soup.find_all('div',attrs={'class':'MKiFS6'}):
  ratings.append(x.text if x else np.nan)
  #diplay all ratings
  for name in ratings:
    print(name)

# %%
price=soup.find('div',attrs={'class':'hZ3P6w DeU9vF'})
price

# %%
price=[]
for x in soup.find_all('div',attrs={'class':'hZ3P6w DeU9vF'}):
  price.append(x.text if x else np.nan)
  #diplay all price
  for name in price:
    print(name)

# %%
discount=soup.find('div',attrs={'class':'HQe8jr'})
discount

# %%
discount=[]
for x in soup.find_all('div',attrs={'class':'HQe8jr'}):
  discount.append(x.text if x else np.nan)
  #diplay all discount
  for name in discount:
    print(name)

# %%
specifications=soup.find('div',attrs={'class':'CMXw7N'})
specifications

# %%
specifications=[]
for x in soup.find_all('div',attrs={'class':'CMXw7N'}):
  specifications.append(x.text if x else np.nan)
  #diplay all specifications
  for name in specifications:
    print(name)

# %%
for i in range (1,103):
  url=f'https://www.flipkart.com/search?q=laptop&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&as-pos=1&as-type=RECENT&suggestionId=laptop%7CLaptops&requestId=3f3ea89d-e660-48a9-b1a4-5c9c322da66e&as-searchtext=Lapt&page={i}'
  print(url)
# Out:
# https://www.flipkart.com/search?q=laptop&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&as-pos=1&as-type=RECENT&suggestionId=laptop%7CLaptops&requestId=3f3ea89d-e660-48a9-b1a4-5c9c322da66e&as-searchtext=Lapt&page=1
# https://www.flipkart.com/search?q=laptop&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&as-pos=1&as-type=RECENT&suggestionId=laptop%7CLaptops&requestId=3f3ea89d-e660-48a9-b1a4-5c9c322da66e&as-searchtext=Lapt&page=2
# https://www.flipkart.com/search?q=laptop&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&as-pos=1&as-type=RECENT&suggestionId=laptop%7CLaptops&requestId=3f3ea89d-e660-48a9-b1a4-5c9c322da66e&as-searchtext=Lapt&page=3
# ...

# %%
from bs4 import BeautifulSoup
import requests
import numpy as np
import time

productname = []
price = []
rating = []
features = []
pagenum = []
original_price = []
Discount = []
Review = []

total_time = time.time()

for i in range(1,103):
    start_time = time.time()
    URL = f"https://www.flipkart.com/search?q=laptop&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_4_na_na_na&as-pos=1&as-type=RECENT&suggestionId=laptop%7CLaptops&requestId=3f3ea89d-e660-48a9-b1a4-5c9c322da66e&as-searchtext=Lapt&page={i}"
    page = requests.get(URL)
    soup = BeautifulSoup(page.text, "html.parser")

    for x in soup.find_all('div', attrs={'class':'ZFwe0M row'}):
        pname = x.find('div', attrs={'class':'RG5Slk'})
        cost = x.find('div', attrs={'class':'hZ3P6w DeU9vF'})   # discounted price
        rat = x.find('div', attrs={'class':'MKiFS6'})
        specs = x.find('div', attrs={'class':'CMXw7N'})
        op = x.find('div', attrs={'class':'kRYCnD gxR4EY'})
        discount = x.find('div', attrs={'class':'HQe8jr'})
        reviews = x.find('span', attrs={'class':'PvbNMB'})


        productname.append(pname.text if pname else np.nan)
        price.append(cost.text if cost else np.nan)
        rating.append(rat.text if rat else np.nan)
        features.append(specs.text if specs else np.nan)
        original_price.append(op.text if op else np.nan)
        Discount.append(discount.text if discount else np.nan)
        Review.append(reviews.text if reviews else np.nan)

        pagenum.append(i)

    print(f'Page {i} completed in {time.time()-start_time:.2f} seconds')

print("Total Time Completed in seconds", str(time.time()-total_time))
# Out:
# Page 1 completed in 15.77 seconds
# Page 2 completed in 15.76 seconds
# Page 3 completed in 15.79 seconds
# Page 4 completed in 15.76 seconds
# Page 5 completed in 15.76 seconds
# Page 6 completed in 15.72 seconds
# Page 7 completed in 15.76 seconds
# Page 8 completed in 15.73 seconds
# Page 9 completed in 15.81 seconds
# Page 10 completed in 15.78 seconds
# Page 11 completed in 15.74 seconds
# Page 12 completed in 15.73 seconds
# Page 13 completed in 15.77 seconds
# Page 14 completed in 15.77 seconds
# Page 15 completed in 15.78 seconds
# Page 16 completed in 15.78 seconds
# Page 17 completed in 15.77 seconds
# Page 18 completed in 15.76 seconds
# Page 19 completed in 15.78 seconds
# Page 20 completed in 15.77 seconds
# Page 21 completed in 15.75 seconds
# Page 22 completed in 15.73 seconds
# Page 23 completed in 15.75 seconds
# Page 24 completed in 15.73 seconds
# Page 25 completed in 15.78 seconds
# Page 26 completed in 15.77 seconds
# Page 27 completed in 15.78 seconds
# ...

# %%
df=pd.DataFrame({'product_name':productname,'price':price,'Ratings':rating,'Features/Specifications':features,'pagenum':pagenum,'Orgina_price':original_price,'Discount':Discount,'Review':Review})
df
# Out:
# Empty DataFrame
# Columns: [product_name, price, Ratings, Features/Specifications, pagenum, Orgina_price, Discount, Review]
# Index: []

# %%
df.to_csv('flipkart_laptop_new.csv',index=False)
df
# Out:
# Empty DataFrame
# Columns: [product_name, price, Ratings, Features/Specifications, pagenum, Orgina_price, Discount, Review]
# Index: []

# %%
df=pd.read_csv('flipkart_laptop_new.csv')
df
# Out:
# Empty DataFrame
# Columns: [product_name, price, Ratings, Features/Specifications, pagenum, Orgina_price, Discount, Review]
# Index: []

# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from bs4 import BeautifulSoup
import re
import json
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/laptops_4 (1).csv')
df
# Out:
#                                           product name    Price  ratings  \
# 0    DELL 15 AMD Ryzen 5 Hexa Core 7530U - (16 GB/5...  ₹38,990      4.3
# 1    DELL 15 Intel Core i3 13th Gen 1305U - (16 GB/...  ₹38,990      4.2
# 2    Acer Aspire 3 Intel Celeron Dual Core - (8 GB/...  ₹15,990      3.8
# 3    ASUS Expertbook P1 High-performance processor ...  ₹49,990      4.3
# 4    Lenovo Chromebook MediaTek Kompanio 520 - (4 G...  ₹12,990      3.9
# ..                                                 ...      ...      ...
# 979  ASUS X512FA Intel Core i3 10th Gen - (4 GB/512...  ₹37,899      4.4
# 980  HP Laptop Intel Core i3 13th Gen 1315U - (8 GB...  ₹35,990      4.1
# 981  DELL 15 Intel Core i3 13th Gen 1305U - (16 GB/...  ₹38,990      4.2
# 982  HP Pavilion Intel Core i5 12th Gen 1240P - (8 ...  ₹58,599      4.2
# 983  HP 255 G9 Silver AMD Ryzen 5 Hexa Core AMD Ryz...  ₹36,990      4.1
#
#                                               Features  Page number  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product name    984 non-null    object
#  1   Price           984 non-null    object
#  2   ratings         951 non-null    float64
#  3   Features        984 non-null    object
#  4   Page number     984 non-null    int64
#  5   Original_price  976 non-null    object
#  6   Discount        975 non-null    object
#  7   Review          951 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 61.6+ KB

# %%
df.shape
# Out:
# (984, 8)

# %%
df.isnull().sum()
# Out:
# product name       0
# Price              0
# ratings           33
# Features           0
# Page number        0
# Original_price     8
# Discount           9
# Review            33
# dtype: int64

# %%
df['ratings'].value_counts()
# Out:
# ratings
# 4.1    238
# 4.4    202
# 4.2    155
# 4.3    144
# 4.0     54
# 3.9     30
# 4.5     27
# 3.8     23
# 4.6     11
# 4.7     11
# 3.6     10
# 3.5      8
# 3.7      8
# 3.0      6
# 4.9      6
# 5.0      5
# 3.4      5
# 4.8      3
# 3.3      2
# 2.7      2
# 3.2      1
# Name: count, dtype: int64

# %%
df['ratings'].mode()[0]
# Out:
# np.float64(4.1)

# %%
df['ratings'].fillna(df['ratings'].mode()[0],inplace=True)
df
# Out:
#                                           product name    Price  ratings  \
# 0    DELL 15 AMD Ryzen 5 Hexa Core 7530U - (16 GB/5...  ₹38,990      4.3
# 1    DELL 15 Intel Core i3 13th Gen 1305U - (16 GB/...  ₹38,990      4.2
# 2    Acer Aspire 3 Intel Celeron Dual Core - (8 GB/...  ₹15,990      3.8
# 3    ASUS Expertbook P1 High-performance processor ...  ₹49,990      4.3
# 4    Lenovo Chromebook MediaTek Kompanio 520 - (4 G...  ₹12,990      3.9
# ..                                                 ...      ...      ...
# 979  ASUS X512FA Intel Core i3 10th Gen - (4 GB/512...  ₹37,899      4.4
# 980  HP Laptop Intel Core i3 13th Gen 1315U - (8 GB...  ₹35,990      4.1
# 981  DELL 15 Intel Core i3 13th Gen 1305U - (16 GB/...  ₹38,990      4.2
# 982  HP Pavilion Intel Core i5 12th Gen 1240P - (8 ...  ₹58,599      4.2
# 983  HP 255 G9 Silver AMD Ryzen 5 Hexa Core AMD Ryz...  ₹36,990      4.1
#
#                                               Features  Page number  \
# ...

# %%
df['Original_price'].mode(0)

# %%
df['Original_price'].fillna(df['Original_price'].mode()[0],inplace=True)
df
# Out:
#                                           product name    Price  ratings  \
# 0    DELL 15 AMD Ryzen 5 Hexa Core 7530U - (16 GB/5...  ₹38,990      4.3
# 1    DELL 15 Intel Core i3 13th Gen 1305U - (16 GB/...  ₹38,990      4.2
# 2    Acer Aspire 3 Intel Celeron Dual Core - (8 GB/...  ₹15,990      3.8
# 3    ASUS Expertbook P1 High-performance processor ...  ₹49,990      4.3
# 4    Lenovo Chromebook MediaTek Kompanio 520 - (4 G...  ₹12,990      3.9
# ..                                                 ...      ...      ...
# 979  ASUS X512FA Intel Core i3 10th Gen - (4 GB/512...  ₹37,899      4.4
# 980  HP Laptop Intel Core i3 13th Gen 1315U - (8 GB...  ₹35,990      4.1
# 981  DELL 15 Intel Core i3 13th Gen 1305U - (16 GB/...  ₹38,990      4.2
# 982  HP Pavilion Intel Core i5 12th Gen 1240P - (8 ...  ₹58,599      4.2
# 983  HP 255 G9 Silver AMD Ryzen 5 Hexa Core AMD Ryz...  ₹36,990      4.1
#
#                                               Features  Page number  \
# ...

# %%
df['Discount'].fillna(df['Discount'].mode()[0],inplace=True)
df
# Out:
#                                           product name    Price  ratings  \
# 0    DELL 15 AMD Ryzen 5 Hexa Core 7530U - (16 GB/5...  ₹38,990      4.3
# 1    DELL 15 Intel Core i3 13th Gen 1305U - (16 GB/...  ₹38,990      4.2
# 2    Acer Aspire 3 Intel Celeron Dual Core - (8 GB/...  ₹15,990      3.8
# 3    ASUS Expertbook P1 High-performance processor ...  ₹49,990      4.3
# 4    Lenovo Chromebook MediaTek Kompanio 520 - (4 G...  ₹12,990      3.9
# ..                                                 ...      ...      ...
# 979  ASUS X512FA Intel Core i3 10th Gen - (4 GB/512...  ₹37,899      4.4
# 980  HP Laptop Intel Core i3 13th Gen 1315U - (8 GB...  ₹35,990      4.1
# 981  DELL 15 Intel Core i3 13th Gen 1305U - (16 GB/...  ₹38,990      4.2
# 982  HP Pavilion Intel Core i5 12th Gen 1240P - (8 ...  ₹58,599      4.2
# 983  HP 255 G9 Silver AMD Ryzen 5 Hexa Core AMD Ryz...  ₹36,990      4.1
#
#                                               Features  Page number  \
# ...

# %%
df['Review'].fillna(df['Review'].mode()[0],inplace=True)
df
# Out:
#                                           product name    Price  ratings  \
# 0    DELL 15 AMD Ryzen 5 Hexa Core 7530U - (16 GB/5...  ₹38,990      4.3
# 1    DELL 15 Intel Core i3 13th Gen 1305U - (16 GB/...  ₹38,990      4.2
# 2    Acer Aspire 3 Intel Celeron Dual Core - (8 GB/...  ₹15,990      3.8
# 3    ASUS Expertbook P1 High-performance processor ...  ₹49,990      4.3
# 4    Lenovo Chromebook MediaTek Kompanio 520 - (4 G...  ₹12,990      3.9
# ..                                                 ...      ...      ...
# 979  ASUS X512FA Intel Core i3 10th Gen - (4 GB/512...  ₹37,899      4.4
# 980  HP Laptop Intel Core i3 13th Gen 1315U - (8 GB...  ₹35,990      4.1
# 981  DELL 15 Intel Core i3 13th Gen 1305U - (16 GB/...  ₹38,990      4.2
# 982  HP Pavilion Intel Core i5 12th Gen 1240P - (8 ...  ₹58,599      4.2
# 983  HP 255 G9 Silver AMD Ryzen 5 Hexa Core AMD Ryz...  ₹36,990      4.1
#
#                                               Features  Page number  \
# ...

# %%
df.isnull().sum()
# Out:
# product name      0
# Price             0
# ratings           0
# Features          0
# Page number       0
# Original_price    0
# Discount          0
# Review            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head(1)
# Out:
#                                         product name    Price  ratings  \
# 0  DELL 15 AMD Ryzen 5 Hexa Core 7530U - (16 GB/5...  ₹38,990      4.3
#
#                                             Features  Page number  \
# 0  AMD Ryzen 5 Hexa Core Processor16 GB DDR4 RAMW...            1
#
#   Original_price Discount                       Review
# 0        ₹56,919  31% off  2,013 Ratings & 135 Reviews

# %%
df['product name']
# Out:
# 0      DELL 15 AMD Ryzen 5 Hexa Core 7530U - (16 GB/5...
# 1      DELL 15 Intel Core i3 13th Gen 1305U - (16 GB/...
# 2      Acer Aspire 3 Intel Celeron Dual Core - (8 GB/...
# 3      ASUS Expertbook P1 High-performance processor ...
# 4      Lenovo Chromebook MediaTek Kompanio 520 - (4 G...
#                              ...
# 979    ASUS X512FA Intel Core i3 10th Gen - (4 GB/512...
# 980    HP Laptop Intel Core i3 13th Gen 1315U - (8 GB...
# 981    DELL 15 Intel Core i3 13th Gen 1305U - (16 GB/...
# 982    HP Pavilion Intel Core i5 12th Gen 1240P - (8 ...
# 983    HP 255 G9 Silver AMD Ryzen 5 Hexa Core AMD Ryz...
# Name: product name, Length: 983, dtype: object

# %%
df['Brand'] = df['product name'].apply(lambda x: re.findall(r'^\w+', x)[0])
df['Brand']
# Out:
# 0        DELL
# 1        DELL
# 2        Acer
# 3        ASUS
# 4      Lenovo
#         ...
# 979      ASUS
# 980        HP
# 981      DELL
# 982        HP
# 983        HP
# Name: Brand, Length: 983, dtype: object

# %%
df.head(1)
# Out:
#                                         product name    Price  ratings  \
# 0  DELL 15 AMD Ryzen 5 Hexa Core 7530U - (16 GB/5...  ₹38,990      4.3
#
#                                             Features  Page number  \
# 0  AMD Ryzen 5 Hexa Core Processor16 GB DDR4 RAMW...            1
#
#   Original_price Discount                       Review Brand
# 0        ₹56,919  31% off  2,013 Ratings & 135 Reviews  DELL

# %%
df['Processor']=df['Features'].apply(lambda x: re.findall(r'^\w+', x)[0])
df['Processor']
# Out:
# 0           AMD
# 1         Intel
# 2         Intel
# 3         Intel
# 4      MediaTek
#          ...
# 979       Intel
# 980       Intel
# 981       Intel
# 982       Intel
# 983         AMD
# Name: Processor, Length: 983, dtype: object

# %%
df['Processor'].value_counts()
# Out:
# Processor
# Intel         568
# AMD           264
# Qualcomm      128
# Apple          13
# MediaTek        8
# Snapdragon      1
# Processor       1
# Name: count, dtype: int64

# %%
df.head(1)
# Out:
#                                         product name    Price  ratings  \
# 0  DELL 15 AMD Ryzen 5 Hexa Core 7530U - (16 GB/5...  ₹38,990      4.3
#
#                                             Features  Page number  \
# 0  AMD Ryzen 5 Hexa Core Processor16 GB DDR4 RAMW...            1
#
#   Original_price Discount                       Review Brand Processor
# 0        ₹56,919  31% off  2,013 Ratings & 135 Reviews  DELL       AMD

# %%
df['Ratings1']=df['Review'].apply(lambda x:re.split(r'[&]',x)[0])
df
# Out:
#                                           product name    Price  ratings  \
# 0    DELL 15 AMD Ryzen 5 Hexa Core 7530U - (16 GB/5...  ₹38,990      4.3
# 1    DELL 15 Intel Core i3 13th Gen 1305U - (16 GB/...  ₹38,990      4.2
# 2    Acer Aspire 3 Intel Celeron Dual Core - (8 GB/...  ₹15,990      3.8
# 3    ASUS Expertbook P1 High-performance processor ...  ₹49,990      4.3
# 4    Lenovo Chromebook MediaTek Kompanio 520 - (4 G...  ₹12,990      3.9
# ..                                                 ...      ...      ...
# 979  ASUS X512FA Intel Core i3 10th Gen - (4 GB/512...  ₹37,899      4.4
# 980  HP Laptop Intel Core i3 13th Gen 1315U - (8 GB...  ₹35,990      4.1
# 981  DELL 15 Intel Core i3 13th Gen 1305U - (16 GB/...  ₹38,990      4.2
# 982  HP Pavilion Intel Core i5 12th Gen 1240P - (8 ...  ₹58,599      4.2
# 983  HP 255 G9 Silver AMD Ryzen 5 Hexa Core AMD Ryz...  ₹36,990      4.1
#
#                                               Features  Page number  \
# ...

# %%
df['Ratings1']=df['Ratings1'].apply(lambda x:re.split(r'[&]',x)[0])

# %%
df['Ratings1']
# Out:
# 0      2,013 Ratings
# 1        399 Ratings
# 2      6,774 Ratings
# 3      3,463 Ratings
# 4      3,181 Ratings
#             ...
# 979      851 Ratings
# 980    2,057 Ratings
# 981      399 Ratings
# 982      813 Ratings
# 983      249 Ratings
# Name: Ratings1, Length: 983, dtype: object

# %%
df['no_of_Ratings']=df['Ratings1'].apply(lambda x: re.findall(r'[\d,]+',x)[0].replace(',', '')).astype('int')

# %%
df['no_of_Ratings']
# Out:
# 0      2013
# 1       399
# 2      6774
# 3      3463
# 4      3181
#        ...
# 979     851
# 980    2057
# 981     399
# 982     813
# 983     249
# Name: no_of_Ratings, Length: 983, dtype: int64

# %%
df['Reviews1']=df['Review'].apply(lambda x:re.split(r'[&]',x)[0])
df['Reviews1']
# Out:
# 0      2,013 Ratings
# 1        399 Ratings
# 2      6,774 Ratings
# 3      3,463 Ratings
# 4      3,181 Ratings
#             ...
# 979      851 Ratings
# 980    2,057 Ratings
# 981      399 Ratings
# 982      813 Ratings
# 983      249 Ratings
# Name: Reviews1, Length: 983, dtype: object

# %%
df['no_of_Reviews'] = df['Reviews1'].apply(lambda x: re.findall(r'[\d,]+',x)[0].replace(',', '')).astype('int')
df['no_of_Reviews']
# Out:
# 0      2013
# 1       399
# 2      6774
# 3      3463
# 4      3181
#        ...
# 979     851
# 980    2057
# 981     399
# 982     813
# 983     249
# Name: no_of_Reviews, Length: 983, dtype: int64

# %%
df.head(1)
# Out:
#                                         product name    Price  ratings  \
# 0  DELL 15 AMD Ryzen 5 Hexa Core 7530U - (16 GB/5...  ₹38,990      4.3
#
#                                             Features  Page number  \
# 0  AMD Ryzen 5 Hexa Core Processor16 GB DDR4 RAMW...            1
#
#   Original_price Discount                       Review Brand Processor  \
# 0        ₹56,919  31% off  2,013 Ratings & 135 Reviews  DELL       AMD
#
#          Ratings1  no_of_Ratings        Reviews1  no_of_Reviews
# 0  2,013 Ratings            2013  2,013 Ratings            2013

# %%
df['Price'] = df['Price'].apply(lambda x: re.sub(r'[₹,]', '', x)).astype('int')
df['Price']
# Out:
# 0      38990
# 1      38990
# 2      15990
# 3      49990
# 4      12990
#        ...
# 979    37899
# 980    35990
# 981    38990
# 982    58599
# 983    36990
# Name: Price, Length: 983, dtype: int64

# %%
df['Original_price']=df['Original_price'].apply(lambda x: re.sub(r'[₹,]','',x)).astype('int')
df['Original_price']
# Out:
# 0      56919
# 1      54479
# 2      32990
# 3      89990
# 4      28690
#        ...
# 979    40870
# 980    52115
# 981    54479
# 982    75494
# 983    54000
# Name: Original_price, Length: 983, dtype: int64

# %%
df['Features'][0]
# Out:
# 'AMD Ryzen 5 Hexa Core Processor16 GB DDR4 RAMWindows 11 Operating System512 GB SSD39.62 cm (15.6 Inch) DisplayMy Dell (Dell Power Manager,Dell Support Assist)1 Year Onsite Warranty'

# %%
df['GB_List']=df['Features'].apply(lambda x:re.findall(r'(\d+)\s*GB',x))
df['GB_List']
# Out:
# 0      [16, 512]
# 1      [16, 512]
# 2       [8, 128]
# 3      [16, 512]
# 4            [4]
#          ...
# 979     [4, 512]
# 980     [8, 512]
# 981    [16, 512]
# 982     [8, 512]
# 983     [8, 512]
# Name: GB_List, Length: 983, dtype: object

# %%
df['RAM']=df['GB_List'].apply(lambda x:(x[0].replace(' GB', '')) if len(x)>0 else np.nan)
df['RAM']
# Out:
# 0      16
# 1      16
# 2       8
# 3      16
# 4       4
#        ..
# 979     4
# 980     8
# 981    16
# 982     8
# 983     8
# Name: RAM, Length: 983, dtype: object

# %%
df['Storage']=df['GB_List'].apply(lambda x:x[1]if len(x)>1 else np.nan)
df['Storage']
# Out:
# 0      512
# 1      512
# 2      128
# 3      512
# 4      NaN
#       ...
# 979    512
# 980    512
# 981    512
# 982    512
# 983    512
# Name: Storage, Length: 983, dtype: object

# %%
df.shape
# Out:
# (983, 17)

# %%
df.columns
# Out:
# Index(['product name', 'Price', 'ratings', 'Features', 'Page number',
#        'Original_price', 'Discount', 'Review', 'Brand', 'Processor',
#        'Ratings1', 'no_of_Ratings', 'Reviews1', 'no_of_Reviews', 'GB_List',
#        'RAM', 'Storage'],
#       dtype='object')

# %%
df.drop(columns=['product name','Features','Review', 'Ratings1', 'Reviews1','GB_List'],inplace=True)

# %%
df.head(1)
# Out:
#    Price  ratings  Page number  Original_price Discount Brand Processor  \
# 0  38990      4.3            1           56919  31% off  DELL       AMD
#
#    no_of_Ratings  no_of_Reviews RAM Storage
# 0           2013           2013  16     512

# %%
df['Discount']=df['Discount'].apply(lambda x :re.findall(r'[\d%]+',x)[0])
df['Discount']
# Out:
# 0      31%
# 1      28%
# 2      51%
# 3      44%
# 4      54%
#       ...
# 979     7%
# 980    30%
# 981    28%
# 982    22%
# 983    31%
# Name: Discount, Length: 983, dtype: object

# %%
df.columns
# Out:
# Index(['Price', 'ratings', 'Page number', 'Original_price', 'Discount',
#        'Brand', 'Processor', 'no_of_Ratings', 'no_of_Reviews', 'RAM',
#        'Storage'],
#       dtype='object')

# %%
df
# Out:
#      Price  ratings  Page number  Original_price Discount   Brand Processor  \
# 0    38990      4.3            1           56919      31%    DELL       AMD
# 1    38990      4.2            1           54479      28%    DELL     Intel
# 2    15990      3.8            1           32990      51%    Acer     Intel
# 3    49990      4.3            1           89990      44%    ASUS     Intel
# 4    12990      3.9            1           28690      54%  Lenovo  MediaTek
# ..     ...      ...          ...             ...      ...     ...       ...
# 979  37899      4.4           41           40870       7%    ASUS     Intel
# 980  35990      4.1           41           52115      30%      HP     Intel
# 981  38990      4.2           41           54479      28%    DELL     Intel
# 982  58599      4.2           41           75494      22%      HP     Intel
# 983  36990      4.1           41           54000      31%      HP       AMD
#
#      no_of_Ratings  no_of_Reviews RAM Storage
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 983 entries, 0 to 983
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Price           983 non-null    int64
#  1   ratings         983 non-null    float64
#  2   Page number     983 non-null    int64
#  3   Original_price  983 non-null    int64
#  4   Discount        983 non-null    object
#  5   Brand           983 non-null    object
#  6   Processor       983 non-null    object
#  7   no_of_Ratings   983 non-null    int64
#  8   no_of_Reviews   983 non-null    int64
#  9   RAM             983 non-null    object
#  10  Storage         877 non-null    object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 124.4+ KB

# %%
df['Storage'].isnull().sum()
# Out:
# np.int64(106)

# %%
df['Storage'].fillna(df['Storage'].mode()[0],inplace=True)

# %%
df['Storage']=df['Storage'].astype('int')

# %%
df
# Out:
#      Price  ratings  Page number  Original_price Discount   Brand Processor  \
# 0    38990      4.3            1           56919      31%    DELL       AMD
# 1    38990      4.2            1           54479      28%    DELL     Intel
# 2    15990      3.8            1           32990      51%    Acer     Intel
# 3    49990      4.3            1           89990      44%    ASUS     Intel
# 4    12990      3.9            1           28690      54%  Lenovo  MediaTek
# ..     ...      ...          ...             ...      ...     ...       ...
# 979  37899      4.4           41           40870       7%    ASUS     Intel
# 980  35990      4.1           41           52115      30%      HP     Intel
# 981  38990      4.2           41           54479      28%    DELL     Intel
# 982  58599      4.2           41           75494      22%      HP     Intel
# 983  36990      4.1           41           54000      31%      HP       AMD
#
#      no_of_Ratings  no_of_Reviews RAM  Storage
# ...

# %%
df.isnull().sum()
# Out:
# Price             0
# ratings           0
# Page number       0
# Original_price    0
# Discount          0
# Brand             0
# Processor         0
# no_of_Ratings     0
# no_of_Reviews     0
# RAM               0
# Storage           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv('cleaned_laptops_new.csv',index=False)

# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from bs4 import BeautifulSoup
import re
import json
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/cleaned_laptops_new.csv')
df
# Out:
#      Price  ratings  Page number  Original_price Discount   Brand Processor  \
# 0    38990      4.3            1           56919      31%    DELL       AMD
# 1    38990      4.2            1           54479      28%    DELL     Intel
# 2    15990      3.8            1           32990      51%    Acer     Intel
# 3    49990      4.3            1           89990      44%    ASUS     Intel
# 4    12990      3.9            1           28690      54%  Lenovo  MediaTek
# ..     ...      ...          ...             ...      ...     ...       ...
# 978  37899      4.4           41           40870       7%    ASUS     Intel
# 979  35990      4.1           41           52115      30%      HP     Intel
# 980  38990      4.2           41           54479      28%    DELL     Intel
# 981  58599      4.2           41           75494      22%      HP     Intel
# 982  36990      4.1           41           54000      31%      HP       AMD
#
#      no_of_Ratings  no_of_Reviews  RAM  Storage
# ...

# %%
df.isnull().sum()
# Out:
# Price             0
# ratings           0
# Page number       0
# Original_price    0
# Discount          0
# Brand             0
# Processor         0
# no_of_Ratings     0
# no_of_Reviews     0
# RAM               0
# Storage           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head(1)
# Out:
#    Price  ratings  Page number  Original_price Discount Brand Processor  \
# 0  38990      4.3            1           56919      31%  DELL       AMD
#
#    no_of_Ratings  no_of_Reviews  RAM  Storage
# 0           2013           2013   16      512

# %% [markdown]
# univarient analyis

# %%
df['Brand'].value_counts().head(8)
# Out:
# Brand
# HP         251
# ASUS       197
# DELL       149
# Lenovo     118
# Acer       115
# Samsung     62
# MSI         42
# Apple       13
# Name: count, dtype: int64

# %%
df['Brand'].value_counts().head(8).plot(kind='bar',figsize=(10,5))
# Out:
# <Axes: xlabel='Brand'>

# %%
df['Processor'].value_counts().head().plot(kind='bar')
# Out:
# <Axes: xlabel='Processor'>

# %%
sns.histplot(x=df['Price'],data=df)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
sns.histplot(x=df['Price'], kde=True, data=df)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
sns.boxplot(x=df['Price'],data=df)
# Out:
# <Axes: xlabel='Price'>

# %%
q1=df['Price'].quantile(0.25)
q3=df['Price'].quantile(0.75)
iqr=q3-q1
outliers=df[(df['Price']<q1-1.5*iqr)|(df['Price']>q3+1.5*iqr)]
outliers
# Out:
#       Price  ratings  Page number  Original_price Discount    Brand Processor  \
# 54   119990      4.0            3          162090      25%   Lenovo     Intel
# 133  144699      4.1            6          154900       6%    Apple     Apple
# 333  112990      4.1           14          132590      14%   Lenovo       AMD
# 387  157990      4.6           17          191099      17%       HP     Intel
# 431  124900      4.7           19           92990      41%    Apple     Apple
# 433  112990      4.1           19          132590      14%   Lenovo       AMD
# 448  169900      4.1           19           92990      41%    Apple     Apple
# 462  131990      3.5           20          138490       4%     DELL     Intel
# 482  129990      4.6           21          151990      14%      MSI     Intel
# 503  157990      4.6           22          191099      17%       HP     Intel
# 511  175990      4.5           22          193990       9%      MSI     Intel
# ...

# %%
outliers['Brand'].value_counts()
# Out:
# Brand
# Lenovo     8
# Apple      8
# Samsung    7
# HP         6
# ASUS       5
# Acer       4
# MSI        3
# DELL       2
# Name: count, dtype: int64

# %%
outliers['Brand'].value_counts().head().plot(kind='bar')
# Out:
# <Axes: xlabel='Brand'>

# %% [markdown]
# bivarient analysis

# %%
sns.scatterplot(x='ratings',y='RAM',data=df)
# Out:
# <Axes: xlabel='ratings', ylabel='RAM'>

# %%
sns.violinplot(x='RAM',y='Price',data=df)
# Out:
# <Axes: xlabel='RAM', ylabel='Price'>

# %% [markdown]
# multivarient analysis

# %%
sns.scatterplot(x='ratings',y='Price',hue='RAM',data=df)
# Out:
# <Axes: xlabel='ratings', ylabel='Price'>

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.select_dtypes(include='number').corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >
